# %%
import caveclient
from caveclient import CAVEclient

# %%
import caveclient
print(caveclient.__version__)
# Out:
# 8.0.1

# %%
client = CAVEclient()

auth = client.auth
print(f"My current token is: {auth.token}")
# Out:
# My current token is: 5475aa0fff3178291f8259e9d7894e68

# %%
client.auth.save_token(token="5475aa0fff3178291f8259e9d7894e68")
