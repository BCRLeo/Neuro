# %%
import caveclient
from caveclient import CAVEclient

# %%
import caveclient
print(caveclient.__version__)
# Out:
# 8.0.1

# %%
client.auth.save_token(token="93a17214040dfc83f49ccd801df18b82")

# %%
client = CAVEclient()

auth = client.auth
print(f"My current token is: {auth.token}")
# Out:
# My current token is: 93a17214040dfc83f49ccd801df18b82
